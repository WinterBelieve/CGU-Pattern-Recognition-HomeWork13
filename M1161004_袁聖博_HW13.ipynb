# %% [markdown]
# # Best practices for the real world

# %% [markdown]
# ## Getting the most out of your models

# %% [markdown]
# ### Hyperparameter optimization

# %% [markdown]
# #### Using KerasTuner

# %%
# !pip install keras-tuner -q
# Out:
#      |████████████████████████████████| 135 kB 7.2 MB/s
#      |████████████████████████████████| 1.6 MB 44.6 MB/s

# %% [markdown]
# **A KerasTuner model-building function**

# %%
from tensorflow import keras
from tensorflow.keras import layers

def build_model(hp):
    units = hp.Int(name="units", min_value=16, max_value=64, step=16)
    model = keras.Sequential([
        layers.Dense(units, activation="relu"),
        layers.Dense(10, activation="softmax")
    ])
    optimizer = hp.Choice(name="optimizer", values=["rmsprop", "adam"])
    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])
    return model

# %% [markdown]
# **A KerasTuner `HyperModel`**

# %%
import kerastuner as kt

class SimpleMLP(kt.HyperModel):
    def __init__(self, num_classes):
        self.num_classes = num_classes

    def build(self, hp):
        units = hp.Int(name="units", min_value=16, max_value=64, step=16)
        model = keras.Sequential([
            layers.Dense(units, activation="relu"),
            layers.Dense(self.num_classes, activation="softmax")
        ])
        optimizer = hp.Choice(name="optimizer", values=["rmsprop", "adam"])
        model.compile(
            optimizer=optimizer,
            loss="sparse_categorical_crossentropy",
            metrics=["accuracy"])
        return model

hypermodel = SimpleMLP(num_classes=10)
# Out:
# <ipython-input-3-643dcc05e516>:1: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   import kerastuner as kt

# %%
tuner = kt.BayesianOptimization(
    build_model,
    objective="val_accuracy",
    max_trials=100,
    executions_per_trial=2,
    directory="mnist_kt_test",
    overwrite=True,
)

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 2
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 64, 'step': 16, 'sampling': None}
# optimizer (Choice)
# {'default': 'rmsprop', 'conditions': [], 'values': ['rmsprop', 'adam'], 'ordered': False}

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = x_train.reshape((-1, 28 * 28)).astype("float32") / 255
x_test = x_test.reshape((-1, 28 * 28)).astype("float32") / 255
x_train_full = x_train[:]
y_train_full = y_train[:]
num_val_samples = 10000
x_train, x_val = x_train[:-num_val_samples], x_train[-num_val_samples:]
y_train, y_val = y_train[:-num_val_samples], y_train[-num_val_samples:]
callbacks = [
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=5),
]
tuner.search(
    x_train, y_train,
    batch_size=128,
    epochs=100,
    validation_data=(x_val, y_val),
    callbacks=callbacks,
    verbose=2,
)
# Out:
# Trial 100 Complete [00h 00m 48s]
# val_accuracy: 0.9734500050544739
#
# Best val_accuracy So Far: 0.9763000011444092
# Total elapsed time: 01h 37m 31s

# %% [markdown]
# **Querying the best hyperparameter configurations**

# %%
top_n = 4
best_hps = tuner.get_best_hyperparameters(top_n)

# %%
def get_best_epoch(hp):
    model = build_model(hp)
    callbacks=[
        keras.callbacks.EarlyStopping(
            monitor="val_loss", mode="min", patience=10)
    ]
    history = model.fit(
        x_train, y_train,
        validation_data=(x_val, y_val),
        epochs=100,
        batch_size=128,
        callbacks=callbacks)
    val_loss_per_epoch = history.history["val_loss"]
    best_epoch = val_loss_per_epoch.index(min(val_loss_per_epoch)) + 1
    print(f"Best epoch: {best_epoch}")
    return best_epoch

# %%
model = build_model(hp)
def get_best_trained_model(hp):
    best_epoch = get_best_epoch(hp)
    model.fit(
        x_train_full, y_train_full,
        batch_size=128, epochs=int(best_epoch * 1.2))
    return model

best_models = []
for hp in best_hps:
    model = get_best_trained_model(hp)
    model.evaluate(x_test, y_test)
    best_models.append(model)
# Out:
# Epoch 1/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.4274 - accuracy: 0.8843 - val_loss: 0.2377 - val_accuracy: 0.9335
# Epoch 2/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2225 - accuracy: 0.9364 - val_loss: 0.1881 - val_accuracy: 0.9479
# Epoch 3/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1719 - accuracy: 0.9510 - val_loss: 0.1534 - val_accuracy: 0.9579
# Epoch 4/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1394 - accuracy: 0.9600 - val_loss: 0.1379 - val_accuracy: 0.9610
# Epoch 5/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.1175 - accuracy: 0.9664 - val_loss: 0.1200 - val_accuracy: 0.9657
# Epoch 6/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1002 - accuracy: 0.9714 - val_loss: 0.1186 - val_accuracy: 0.9657
# Epoch 7/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0880 - accuracy: 0.9746 - val_loss: 0.1130 - val_accuracy: 0.9669
# Epoch 8/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0780 - accuracy: 0.9774 - val_loss: 0.1046 - val_accuracy: 0.9697
# Epoch 9/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0700 - accuracy: 0.9801 - val_loss: 0.0967 - val_accuracy: 0.9730
# Epoch 10/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0628 - accuracy: 0.9817 - val_loss: 0.0973 - val_accuracy: 0.9718
# Epoch 11/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0577 - accuracy: 0.9828 - val_loss: 0.0966 - val_accuracy: 0.9738
# Epoch 12/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0524 - accuracy: 0.9846 - val_loss: 0.0965 - val_accuracy: 0.9709
# Epoch 13/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0481 - accuracy: 0.9864 - val_loss: 0.0971 - val_accuracy: 0.9728
# Epoch 14/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0436 - accuracy: 0.9878 - val_loss: 0.0990 - val_accuracy: 0.9726
# Epoch 15/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0403 - accuracy: 0.9884 - val_loss: 0.1015 - val_accuracy: 0.9728
# Epoch 16/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0367 - accuracy: 0.9896 - val_loss: 0.0929 - val_accuracy: 0.9752
# Epoch 17/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0339 - accuracy: 0.9905 - val_loss: 0.0909 - val_accuracy: 0.9756
# Epoch 18/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0311 - accuracy: 0.9915 - val_loss: 0.1047 - val_accuracy: 0.9726
# Epoch 19/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0289 - accuracy: 0.9923 - val_loss: 0.0954 - val_accuracy: 0.9756
# Epoch 20/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0265 - accuracy: 0.9927 - val_loss: 0.0990 - val_accuracy: 0.9753
# Epoch 21/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0245 - accuracy: 0.9938 - val_loss: 0.0966 - val_accuracy: 0.9744
# Epoch 22/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0224 - accuracy: 0.9942 - val_loss: 0.1002 - val_accuracy: 0.9756
# Epoch 23/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0208 - accuracy: 0.9947 - val_loss: 0.1024 - val_accuracy: 0.9759
# Epoch 24/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0192 - accuracy: 0.9950 - val_loss: 0.1015 - val_accuracy: 0.9769
# Epoch 25/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0180 - accuracy: 0.9954 - val_loss: 0.1023 - val_accuracy: 0.9762
# Epoch 26/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0160 - accuracy: 0.9962 - val_loss: 0.1066 - val_accuracy: 0.9748
# Epoch 27/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0146 - accuracy: 0.9967 - val_loss: 0.1095 - val_accuracy: 0.9749
# Best epoch: 17
# Epoch 1/20
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3958 - accuracy: 0.8943
# Epoch 2/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1980 - accuracy: 0.9438
# Epoch 3/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1503 - accuracy: 0.9565
# Epoch 4/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1222 - accuracy: 0.9644
# Epoch 5/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1031 - accuracy: 0.9699
# Epoch 6/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0899 - accuracy: 0.9742
# Epoch 7/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0784 - accuracy: 0.9773
# Epoch 8/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0709 - accuracy: 0.9792
# Epoch 9/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0634 - accuracy: 0.9817
# Epoch 10/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0573 - accuracy: 0.9832
# Epoch 11/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0526 - accuracy: 0.9843
# Epoch 12/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0482 - accuracy: 0.9862
# Epoch 13/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0439 - accuracy: 0.9874
# Epoch 14/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0405 - accuracy: 0.9879
# Epoch 15/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0380 - accuracy: 0.9893
# Epoch 16/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0349 - accuracy: 0.9903
# Epoch 17/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0328 - accuracy: 0.9906
# Epoch 18/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0302 - accuracy: 0.9918
# Epoch 19/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0277 - accuracy: 0.9926
# Epoch 20/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0257 - accuracy: 0.9930
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0913 - accuracy: 0.9758
# Epoch 1/100
# 391/391 [==============================] - 2s 3ms/step - loss: 0.4297 - accuracy: 0.8832 - val_loss: 0.2304 - val_accuracy: 0.9373
# Epoch 2/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2212 - accuracy: 0.9369 - val_loss: 0.1781 - val_accuracy: 0.9504
# Epoch 3/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1714 - accuracy: 0.9503 - val_loss: 0.1485 - val_accuracy: 0.9582
# Epoch 4/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1412 - accuracy: 0.9587 - val_loss: 0.1423 - val_accuracy: 0.9597
# Epoch 5/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1202 - accuracy: 0.9646 - val_loss: 0.1234 - val_accuracy: 0.9660
# Epoch 6/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1042 - accuracy: 0.9694 - val_loss: 0.1147 - val_accuracy: 0.9686
# Epoch 7/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0923 - accuracy: 0.9730 - val_loss: 0.1070 - val_accuracy: 0.9683
# Epoch 8/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0825 - accuracy: 0.9760 - val_loss: 0.1047 - val_accuracy: 0.9691
# Epoch 9/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0740 - accuracy: 0.9789 - val_loss: 0.1025 - val_accuracy: 0.9705
# Epoch 10/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0669 - accuracy: 0.9807 - val_loss: 0.1032 - val_accuracy: 0.9710
# Epoch 11/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0608 - accuracy: 0.9823 - val_loss: 0.0981 - val_accuracy: 0.9726
# Epoch 12/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0553 - accuracy: 0.9845 - val_loss: 0.0972 - val_accuracy: 0.9731
# Epoch 13/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0511 - accuracy: 0.9857 - val_loss: 0.1003 - val_accuracy: 0.9713
# Epoch 14/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0470 - accuracy: 0.9865 - val_loss: 0.0939 - val_accuracy: 0.9734
# Epoch 15/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0430 - accuracy: 0.9878 - val_loss: 0.0983 - val_accuracy: 0.9736
# Epoch 16/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0398 - accuracy: 0.9892 - val_loss: 0.0988 - val_accuracy: 0.9718
# Epoch 17/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0366 - accuracy: 0.9899 - val_loss: 0.1010 - val_accuracy: 0.9709
# Epoch 18/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0338 - accuracy: 0.9909 - val_loss: 0.1000 - val_accuracy: 0.9733
# Epoch 19/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0307 - accuracy: 0.9917 - val_loss: 0.1001 - val_accuracy: 0.9735
# Epoch 20/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0288 - accuracy: 0.9924 - val_loss: 0.0979 - val_accuracy: 0.9745
# Epoch 21/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0266 - accuracy: 0.9931 - val_loss: 0.1021 - val_accuracy: 0.9736
# Epoch 22/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0249 - accuracy: 0.9933 - val_loss: 0.1034 - val_accuracy: 0.9746
# Epoch 23/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0229 - accuracy: 0.9942 - val_loss: 0.1049 - val_accuracy: 0.9734
# Epoch 24/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0210 - accuracy: 0.9946 - val_loss: 0.1062 - val_accuracy: 0.9741
# Best epoch: 14
# Epoch 1/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0237 - accuracy: 0.9937
# Epoch 2/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0226 - accuracy: 0.9941
# Epoch 3/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0207 - accuracy: 0.9945
# Epoch 4/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0190 - accuracy: 0.9949
# Epoch 5/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0175 - accuracy: 0.9956
# Epoch 6/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0166 - accuracy: 0.9956
# Epoch 7/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0150 - accuracy: 0.9962
# Epoch 8/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0139 - accuracy: 0.9966
# Epoch 9/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0131 - accuracy: 0.9968
# Epoch 10/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0121 - accuracy: 0.9973
# Epoch 11/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0112 - accuracy: 0.9972
# Epoch 12/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0100 - accuracy: 0.9977
# Epoch 13/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0093 - accuracy: 0.9980
# Epoch 14/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0089 - accuracy: 0.9979
# Epoch 15/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0081 - accuracy: 0.9984
# Epoch 16/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0074 - accuracy: 0.9984
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1158 - accuracy: 0.9761
# Epoch 1/100
# 391/391 [==============================] - 2s 3ms/step - loss: 0.4149 - accuracy: 0.8886 - val_loss: 0.2447 - val_accuracy: 0.9295
# Epoch 2/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2197 - accuracy: 0.9372 - val_loss: 0.1795 - val_accuracy: 0.9502
# Epoch 3/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1722 - accuracy: 0.9509 - val_loss: 0.1543 - val_accuracy: 0.9561
# Epoch 4/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1419 - accuracy: 0.9590 - val_loss: 0.1440 - val_accuracy: 0.9598
# Epoch 5/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.1216 - accuracy: 0.9650 - val_loss: 0.1277 - val_accuracy: 0.9628
# Epoch 6/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1071 - accuracy: 0.9691 - val_loss: 0.1177 - val_accuracy: 0.9663
# Epoch 7/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0950 - accuracy: 0.9728 - val_loss: 0.1133 - val_accuracy: 0.9681
# Epoch 8/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0847 - accuracy: 0.9757 - val_loss: 0.1080 - val_accuracy: 0.9690
# Epoch 9/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0759 - accuracy: 0.9786 - val_loss: 0.1074 - val_accuracy: 0.9690
# Epoch 10/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0688 - accuracy: 0.9804 - val_loss: 0.1092 - val_accuracy: 0.9679
# Epoch 11/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0636 - accuracy: 0.9812 - val_loss: 0.1025 - val_accuracy: 0.9716
# Epoch 12/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0575 - accuracy: 0.9838 - val_loss: 0.1013 - val_accuracy: 0.9715
# Epoch 13/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0530 - accuracy: 0.9855 - val_loss: 0.0987 - val_accuracy: 0.9724
# Epoch 14/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0481 - accuracy: 0.9865 - val_loss: 0.0965 - val_accuracy: 0.9726
# Epoch 15/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0447 - accuracy: 0.9877 - val_loss: 0.0995 - val_accuracy: 0.9709
# Epoch 16/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0412 - accuracy: 0.9887 - val_loss: 0.1005 - val_accuracy: 0.9708
# Epoch 17/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0378 - accuracy: 0.9896 - val_loss: 0.1001 - val_accuracy: 0.9711
# Epoch 18/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0351 - accuracy: 0.9900 - val_loss: 0.0991 - val_accuracy: 0.9730
# Epoch 19/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0322 - accuracy: 0.9914 - val_loss: 0.1016 - val_accuracy: 0.9718
# Epoch 20/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0302 - accuracy: 0.9920 - val_loss: 0.1021 - val_accuracy: 0.9719
# Epoch 21/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0279 - accuracy: 0.9930 - val_loss: 0.1042 - val_accuracy: 0.9713
# Epoch 22/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0258 - accuracy: 0.9933 - val_loss: 0.1160 - val_accuracy: 0.9693
# Epoch 23/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0238 - accuracy: 0.9941 - val_loss: 0.1068 - val_accuracy: 0.9710
# Epoch 24/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0217 - accuracy: 0.9942 - val_loss: 0.1140 - val_accuracy: 0.9708
# Best epoch: 14
# Epoch 1/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.9988
# Epoch 2/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0064 - accuracy: 0.9990
# Epoch 3/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0058 - accuracy: 0.9989
# Epoch 4/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0054 - accuracy: 0.9990
# Epoch 5/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0051 - accuracy: 0.9991
# Epoch 6/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0047 - accuracy: 0.9993
# Epoch 7/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0042 - accuracy: 0.9994
# Epoch 8/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0038 - accuracy: 0.9993
# Epoch 9/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0036 - accuracy: 0.9994
# Epoch 10/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0035 - accuracy: 0.9994
# Epoch 11/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0032 - accuracy: 0.9995
# Epoch 12/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0029 - accuracy: 0.9995
# Epoch 13/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0027 - accuracy: 0.9995
# Epoch 14/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0024 - accuracy: 0.9997
# Epoch 15/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0023 - accuracy: 0.9997
# Epoch 16/16
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0020 - accuracy: 0.9996
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1512 - accuracy: 0.9760
# Epoch 1/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.4279 - accuracy: 0.8839 - val_loss: 0.2446 - val_accuracy: 0.9301
# Epoch 2/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2255 - accuracy: 0.9357 - val_loss: 0.1798 - val_accuracy: 0.9501
# Epoch 3/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1737 - accuracy: 0.9488 - val_loss: 0.1586 - val_accuracy: 0.9571
# Epoch 4/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1405 - accuracy: 0.9596 - val_loss: 0.1340 - val_accuracy: 0.9634
# Epoch 5/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1181 - accuracy: 0.9657 - val_loss: 0.1206 - val_accuracy: 0.9659
# Epoch 6/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1021 - accuracy: 0.9699 - val_loss: 0.1128 - val_accuracy: 0.9684
# Epoch 7/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0895 - accuracy: 0.9738 - val_loss: 0.1099 - val_accuracy: 0.9708
# Epoch 8/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0802 - accuracy: 0.9767 - val_loss: 0.1054 - val_accuracy: 0.9705
# Epoch 9/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0722 - accuracy: 0.9795 - val_loss: 0.1048 - val_accuracy: 0.9697
# Epoch 10/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0654 - accuracy: 0.9813 - val_loss: 0.0958 - val_accuracy: 0.9733
# Epoch 11/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0595 - accuracy: 0.9827 - val_loss: 0.0979 - val_accuracy: 0.9711
# Epoch 12/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0544 - accuracy: 0.9841 - val_loss: 0.1062 - val_accuracy: 0.9718
# Epoch 13/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0502 - accuracy: 0.9855 - val_loss: 0.0976 - val_accuracy: 0.9721
# Epoch 14/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0452 - accuracy: 0.9876 - val_loss: 0.0971 - val_accuracy: 0.9730
# Epoch 15/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0423 - accuracy: 0.9884 - val_loss: 0.0978 - val_accuracy: 0.9736
# Epoch 16/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0389 - accuracy: 0.9895 - val_loss: 0.0935 - val_accuracy: 0.9746
# Epoch 17/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0359 - accuracy: 0.9900 - val_loss: 0.0975 - val_accuracy: 0.9750
# Epoch 18/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0331 - accuracy: 0.9909 - val_loss: 0.0994 - val_accuracy: 0.9728
# Epoch 19/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0306 - accuracy: 0.9919 - val_loss: 0.0963 - val_accuracy: 0.9745
# Epoch 20/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0279 - accuracy: 0.9926 - val_loss: 0.1016 - val_accuracy: 0.9744
# Epoch 21/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0258 - accuracy: 0.9930 - val_loss: 0.1052 - val_accuracy: 0.9733
# Epoch 22/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0240 - accuracy: 0.9935 - val_loss: 0.1007 - val_accuracy: 0.9741
# Epoch 23/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0221 - accuracy: 0.9944 - val_loss: 0.1073 - val_accuracy: 0.9723
# Epoch 24/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0206 - accuracy: 0.9945 - val_loss: 0.1050 - val_accuracy: 0.9744
# Epoch 25/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0186 - accuracy: 0.9952 - val_loss: 0.1063 - val_accuracy: 0.9744
# Epoch 26/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0169 - accuracy: 0.9957 - val_loss: 0.1095 - val_accuracy: 0.9747
# Best epoch: 16
# Epoch 1/19
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0019 - accuracy: 0.9997
# Epoch 2/19
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0017 - accuracy: 0.9997
# Epoch 3/19
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 4/19
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 5/19
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 6/19
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0013 - accuracy: 0.9998
# Epoch 7/19
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0012 - accuracy: 0.9998
# Epoch 8/19
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0011 - accuracy: 0.9998
# Epoch 9/19
# 469/469 [==============================] - 1s 3ms/step - loss: 9.4674e-04 - accuracy: 0.9999
# Epoch 10/19
# 469/469 [==============================] - 1s 3ms/step - loss: 7.9455e-04 - accuracy: 0.9999
# Epoch 11/19
# 469/469 [==============================] - 1s 3ms/step - loss: 7.7306e-04 - accuracy: 0.9999
# Epoch 12/19
# 469/469 [==============================] - 1s 3ms/step - loss: 7.1833e-04 - accuracy: 0.9999
# Epoch 13/19
# 469/469 [==============================] - 1s 3ms/step - loss: 5.8896e-04 - accuracy: 0.9999
# Epoch 14/19
# 469/469 [==============================] - 1s 3ms/step - loss: 5.8947e-04 - accuracy: 0.9999
# Epoch 15/19
# 469/469 [==============================] - 1s 3ms/step - loss: 5.6850e-04 - accuracy: 0.9999
# Epoch 16/19
# 469/469 [==============================] - 1s 3ms/step - loss: 5.0256e-04 - accuracy: 0.9999
# Epoch 17/19
# 469/469 [==============================] - 1s 3ms/step - loss: 4.8650e-04 - accuracy: 0.9999
# Epoch 18/19
# 469/469 [==============================] - 1s 3ms/step - loss: 3.9066e-04 - accuracy: 0.9999
# Epoch 19/19
# 469/469 [==============================] - 1s 3ms/step - loss: 4.2130e-04 - accuracy: 0.9999
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1974 - accuracy: 0.9747

# %%
best_models = tuner.get_best_models(top_n)

# %% [markdown]
# #### The art of crafting the right search space

# %% [markdown]
# #### The future of hyperparameter tuning: automated machine learning

# %% [markdown]
# ### Model ensembling

# %% [markdown]
# ## Scaling-up model training

# %% [markdown]
# ### Speeding up training on GPU with mixed precision

# %% [markdown]
# #### Understanding floating-point precision

# %%
import tensorflow as tf
import numpy as np
np_array = np.zeros((2, 2))
tf_tensor = tf.convert_to_tensor(np_array)
tf_tensor.dtype
# Out:
# tf.float64

# %%
np_array = np.zeros((2, 2))
tf_tensor = tf.convert_to_tensor(np_array, dtype="float32")
tf_tensor.dtype
# Out:
# tf.float32

# %% [markdown]
# #### Mixed-precision training in practice

# %%
from tensorflow import keras
keras.mixed_precision.set_global_policy("mixed_float16")

# %% [markdown]
# ### Multi-GPU training

# %% [markdown]
# #### Getting your hands on two or more GPUs

# %% [markdown]
# #### Single-host, multi-device synchronous training

# %% [markdown]
# ### TPU training

# %% [markdown]
# #### Using a TPU via Google Colab

# %% [markdown]
# #### Leveraging step fusing to improve TPU utilization

# %% [markdown]
# ## Summary
